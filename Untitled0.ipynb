# %%
# !apt-get install git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !git clone https://github.com/NeuralRealm/StableFusion
# !cd StableFusion
# !pip install -e .
# Out:
# fatal: destination path 'StableFusion' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
pip install ./StableFusion/e
# Out:
# ERROR: Invalid requirement: './StableFusion/e'
# Hint: It looks like a path. File './StableFusion/e' does not exist.
